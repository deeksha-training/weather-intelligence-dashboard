# %%
touch .env
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 touch .env
#
# NameError: name 'touch' is not defined

# %%
with open(".env", "w") as f:
    f.write("WEATHER_API_KEY=your_api_key_here\n")

# %%
import os
print(os.listdir())
# Out:
# ['.DS_Store', 'requirements.txt', 'untitled.env', 'Untitled.ipynb', 'README.md', 'logs', '.gitignore', '.env', '.ipynb_checkpoints', 'data', 'notebooks', 'src']

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("WEATHER_API_KEY"))
# Out:
# your_api_key_here

# %%
import os
print(os.getcwd())
# Out:
# /Users/varnit/Documents/Deeksha/Python/weather_dashboard

# %%
import os
print(os.getcwd())
# Out:
# /Users/varnit/Documents/Deeksha/Python/weather_dashboard

# %%
print(os.listdir())
# Out:
# ['.DS_Store', 'requirements.txt', 'untitled.env', 'Untitled.ipynb', 'README.md', 'logs', '.gitignore', '.env', '.ipynb_checkpoints', 'data', 'notebooks', 'src']

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("WEATHER_API_KEY"))
# Out:
# your_api_key_here

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".env")

print(os.getenv("WEATHER_API_KEY"))

# %%
with open(".env", "w") as f:
    f.write("WEATHER_API_KEY=your_api_key_here\n")

# %%
with open(".env", "w") as f:
    f.write("WEATHER_API_KEY=your_api_key_here\n")

# %%
with open(".env", "a+") as f:
    f.seek(0)
    print(f.read())
# Out:
# WEATHER_API_KEY=your_api_key_here

# %%
import os

if os.path.exists(".env"):
    os.remove(".env")
    print(".env deleted")
else:
    print(".env not found")
# Out:
# .env deleted

# %%
print(os.listdir())
# Out:
# ['.DS_Store', 'requirements.txt', 'untitled.env', 'Untitled.ipynb', 'README.md', 'logs', '.gitignore', '.ipynb_checkpoints', 'data', 'notebooks', 'src']

# %%
with open(".env", "w") as f:
    f.write("WEATHER_API_KEY=da7666ee5f1b21024efb1121632cfbb7\n")

# %%
print(os.listdir())
# Out:
# ['.DS_Store', 'requirements.txt', 'untitled.env', 'Untitled.ipynb', 'README.md', 'logs', '.gitignore', '.env', '.ipynb_checkpoints', 'data', 'notebooks', 'src']

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("WEATHER_API_KEY"))
# Out:
# da7666ee5f1b21024efb1121632cfbb7

# %%
import requests
import os

city = "New York"

url = "https://api.openweathermap.org/data/2.5/weather"

params = {
    "q": city,
    "appid": os.getenv("WEATHER_API_KEY"),
    "units": "metric"
}

response = requests.get(url, params=params)

data = response.json()
data
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 33.7,
#   'feels_like': 38.74,
#   'temp_min': 32.12,
#   'temp_max': 34.97,
#   'pressure': 1004,
#   'humidity': 53,
#   'sea_level': 1004,
#   'grnd_level': 1002},
#  'visibility': 10000,
#  'wind': {'speed': 7.6, 'deg': 295, 'gust': 10.28},
#  'clouds': {'all': 63},
#  'dt': 1781297862,
#  'sys': {'type': 2,
#   'id': 2008776,
#   'country': 'US',
#   'sunrise': 1781256265,
#   'sunset': 1781310451},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

city = input("Enter city name: ")

url = "https://api.openweathermap.org/data/2.5/weather"

params = {
    "q": city,
    "appid": os.getenv("WEATHER_API_KEY"),
    "units": "metric"
}

response = requests.get(url, params=params)
data = response.json()

data
# Out:
# Enter city name:  Chicago
# {'coord': {'lon': -87.65, 'lat': 41.85},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 27.74,
#   'feels_like': 28.16,
#   'temp_min': 26.74,
#   'temp_max': 28.96,
#   'pressure': 1013,
#   'humidity': 50,
#   'sea_level': 1013,
#   'grnd_level': 991},
#  'visibility': 10000,
#  'wind': {'speed': 1.79, 'deg': 264, 'gust': 3.58},
#  'clouds': {'all': 0},
#  'dt': 1781298528,
#  'sys': {'type': 2,
#   'id': 2075214,
#   'country': 'US',
#   'sunrise': 1781259309,
#   'sunset': 1781313957},
#  'timezone': -18000,
#  'id': 4887398,
#  'name': 'Chicago',
#  'cod': 200}

# %%
{
  "city": data["name"],
  "temp": data["main"]["temp"],
  "humidity": data["main"]["humidity"],
  "weather": data["weather"][0]["description"]
}
# Out:
# {'city': 'Chicago', 'temp': 27.74, 'humidity': 50, 'weather': 'clear sky'}

# %%
import psycopg2
print("working")
# Out:
# working
