# %% [markdown]
# ✅ Read API key from .env
# ✅ Made API request
# ✅ Fetched live weather data
# ✅ Extracted JSON values
# ✅ Displayed useful output

# %%
import os
import requests
import psycopg2

from dotenv import load_dotenv
from datetime import datetime

# %%
#Load API key

load_dotenv()

API_KEY = os.getenv("WEATHER_API_KEY")


# #Fetch weather

# city = input("Enter city name: ")

# url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

# try:
#     response = requests.get(url,timeout=10)
#     data = response.json()

#     # check if city exists
#     if response.status_code != 200:
#         print("City not found. Please enter a valid city name.")

#     else:
#         temperature = data['main']['temp']
#         humidity = data['main']['humidity']
#         weather = data['weather'][0]['description']
#         country = data['sys']['country']

#         print(f"\nCity: {city}")
#         print(f"Country: {country}")
#         print(f"Temperature: {temperature}°C")
#         print(f"Humidity: {humidity}%")
#         print(f"Weather: {weather}")


# except requests.exceptions.RequestException as e:
#     print("API request failed:", e)
# except KeyError as e:
#     print("Unexpected API response. Missing field:", e)

# %% [markdown]
# Convert this into a function:

# %%
def get_weather(city):

    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

    try:
        response = requests.get(url)
        data = response.json()

        if response.status_code != 200:
            print(f"City '{city}' not found.")
            return None

        weather_data = {
            "city": data['name'],
            "country": data['sys']['country'],
            "temperature": data['main']['temp'],
            "humidity": data['main']['humidity'],
            "wind_speed": data['wind']['speed'],
            "weather": data['weather'][0]['description']
        }

        return weather_data

    except Exception as e:
        print("Something went wrong:", e)
        return None

# %%
weather= get_weather("Mumbai")
print (weather)
# Out:
# {'city': 'Mumbai', 'country': 'IN', 'temperature': 30.95, 'humidity': 66, 'wind_speed': 5.81, 'weather': 'broken clouds'}
